# %% [markdown]
# ## Personal Project using NYC Open Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# keep in mind that this set has been renewed and a lot of the records have been stored away
url = 'https://data.cityofnewyork.us/resource/jb7j-dtam.csv'

deaths_df = pd.read_csv(url)

# %%
deaths_df.head()
# Out:
#    year                                      leading_cause     sex  \
# 0  2017                                   All Other Causes  Female
# 1  2017              Malignant Neoplasms (Cancer: C00-C97)  Female
# 2  2017     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 3  2017     Diseases of Heart (I00-I09, I11, I13, I20-I51)    Male
# 4  2017  Mental and Behavioral Disorders due to Acciden...  Female
#
#           race_ethnicity deaths death_rate age_adjusted_death_rate
# 0     Not Stated/Unknown     99        NaN                     NaN
# 1  Other Race/ Ethnicity     16        NaN                     NaN
# 2  Other Race/ Ethnicity     13        NaN                     NaN
# 3  Other Race/ Ethnicity     21        NaN                     NaN
# 4  Other Race/ Ethnicity      3        NaN                     NaN

# %%
deaths_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# year                       1000 non-null int64
# leading_cause              1000 non-null object
# sex                        1000 non-null object
# race_ethnicity             1000 non-null object
# deaths                     1000 non-null object
# death_rate                 843 non-null object
# age_adjusted_death_rate    843 non-null object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
# dropping any rows that have ANY NULLS for values 
#deaths_df.dropna(how = 'any', inplace = True)

# %%
#deaths_df.info()

# %% [markdown]
# ## converting dtype to necessary columns

# %%
deaths_df['leading_cause'].value_counts()

deaths_df['leading_cause'] = deaths_df['leading_cause'].astype('category')

# %%
deaths_df['race_ethnicity'] = deaths_df['race_ethnicity'].astype('category')

# %%
deaths_df['year'] = deaths_df['year'].astype('category')

# %%
deaths_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# year                       1000 non-null category
# leading_cause              1000 non-null category
# sex                        1000 non-null object
# race_ethnicity             1000 non-null category
# deaths                     1000 non-null object
# death_rate                 843 non-null object
# age_adjusted_death_rate    843 non-null object
# dtypes: category(3), object(4)
# memory usage: 36.6+ KB

# %% [markdown]
# ## Analysis

# %%
deaths_df['year'].value_counts()
# Out:
# 2016    145
# 2015    141
# 2011    141
# 2017    136
# 2014    136
# 2012    134
# 2013    133
# 2010     34
# Name: year, dtype: int64

# %% [markdown]
# ## Cleaning up the data

# %%
deaths_df['sex'].value_counts()
# Out:
# F         293
# M         285
# Female    213
# Male      209
# Name: sex, dtype: int64

# %%
# converting the 'F' to female so that all the data is in sync
mask1 = deaths_df['sex'] == 'F'
deaths_df.loc[mask1, 'sex'] = 'Female'

# %%
# converting the 'M' to male so that all the data is in sync
mask2 = deaths_df['sex'] == 'M'
deaths_df.loc[mask2, 'sex'] = 'Male'

# %%
deaths_df['sex'].value_counts()
# Out:
# Female    506
# Male      494
# Name: sex, dtype: int64

# %%
deaths_df['sex'] = deaths_df['sex'].astype('category')

# %% [markdown]
# ### we can see that in 2016 there were many deaths compared to the others. Let's single those out.

# %%
mask3 = deaths_df['year'] == 2016
deaths_df[mask3]
# Out:
#      year                                      leading_cause     sex  \
# 136  2016  Human Immunodeficiency Virus Disease (HIV: B20...  Female
# 137  2016            Influenza (Flu) and Pneumonia (J09-J18)    Male
# 138  2016     Diseases of Heart (I00-I09, I11, I13, I20-I51)    Male
# 139  2016              Malignant Neoplasms (Cancer: C00-C97)    Male
# 140  2016                                   All Other Causes  Female
# ..    ...                                                ...     ...
# 276  2016            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 277  2016                        Diabetes Mellitus (E10-E14)    Male
# 278  2016                          Alzheimer's Disease (G30)  Female
# 279  2016          Cerebrovascular Disease (Stroke: I60-I69)    Male
# 280  2016  Mental and Behavioral Disorders due to Acciden...  Female
#
#                  race_ethnicity deaths    death_rate age_adjusted_death_rate
# 136          Non-Hispanic Black     91  8.7532824809            7.8444021693
# 137  Asian and Pacific Islander    113  19.027765383            22.916327557
# 138  Asian and Pacific Islander    603  101.53754448            117.77966521
# 139  Asian and Pacific Islander    683  115.00852882            121.07853677
# 140       Other Race/ Ethnicity     13           NaN                     NaN
# ..                          ...    ...           ...                     ...
# 276          Non-Hispanic Black    212  20.392262483            16.053811074
# 277  Asian and Pacific Islander     76  12.797435125            14.194347138
# 278          Non-Hispanic Black    158  15.198006945            11.060385285
# 279  Asian and Pacific Islander     95  15.996793906            18.071424317
# 280          Non-Hispanic Black    101  9.7151816547            8.5902035184
#
# [145 rows x 7 columns]

# %% [markdown]
# #### How many were female? And how many where male?

# %%
deaths_df['sex'].value_counts()
# Out:
# Female    506
# Male      494
# Name: sex, dtype: int64

# %%
mask4 = deaths_df['sex'] == 'Female'
deaths_df[mask4]
# Out:
#      year                                      leading_cause     sex  \
# 0    2017                                   All Other Causes  Female
# 1    2017              Malignant Neoplasms (Cancer: C00-C97)  Female
# 2    2017     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 4    2017  Mental and Behavioral Disorders due to Acciden...  Female
# 9    2017  Chronic Liver Disease and Cirrhosis (K70, K73-...  Female
# ..    ...                                                ...     ...
# 991  2010            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 993  2010              Malignant Neoplasms (Cancer: C00-C97)  Female
# 994  2010  Certain Conditions originating in the Perinata...  Female
# 996  2010       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 997  2010     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
#
#                  race_ethnicity deaths death_rate age_adjusted_death_rate
# 0            Not Stated/Unknown     99        NaN                     NaN
# 1         Other Race/ Ethnicity     16        NaN                     NaN
# 2         Other Race/ Ethnicity     13        NaN                     NaN
# 4         Other Race/ Ethnicity      3        NaN                     NaN
# 9         Other Race/ Ethnicity      2        NaN                     NaN
# ..                          ...    ...        ...                     ...
# 991          White Non-Hispanic    707       49.4                    24.8
# 993  Asian and Pacific Islander    414       73.6                    79.9
# 994  Asian and Pacific Islander     18        3.2                       4
# 996                    Hispanic    156       12.8                    15.4
# 997       Other Race/ Ethnicity     50          .                       .
#
# [506 rows x 7 columns]

# %%
mask10 = deaths_df['sex'] == 'Male'
deaths_df[mask10]
# Out:
#      year                                   leading_cause   sex  \
# 3    2017  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Male
# 5    2017                                All Other Causes  Male
# 6    2017       Cerebrovascular Disease (Stroke: I60-I69)  Male
# 7    2017                     Diabetes Mellitus (E10-E14)  Male
# 8    2017                                All Other Causes  Male
# ..    ...                                             ...   ...
# 990  2010         Influenza (Flu) and Pneumonia (J09-J18)  Male
# 992  2010              Assault (Homicide: Y87.1, X85-Y09)  Male
# 995  2010           Malignant Neoplasms (Cancer: C00-C97)  Male
# 998  2010  Diseases of Heart (I00-I09, I11, I13, I20-I51)  Male
# 999  2010                     Diabetes Mellitus (E10-E14)  Male
#
#                  race_ethnicity deaths    death_rate age_adjusted_death_rate
# 3         Other Race/ Ethnicity     21           NaN                     NaN
# 5                      Hispanic   1275  104.44792513            134.38085038
# 6                      Hispanic    191  15.646708784            20.758171269
# 7                      Hispanic    235  19.251186201            25.718023722
# 8            Not Stated/Unknown    137           NaN                     NaN
# ..                          ...    ...           ...                     ...
# 990  Asian and Pacific Islander    108          20.7                    31.7
# 992          Black Non-Hispanic    299          35.1                    35.5
# 995          Not Stated/Unknown     46             .                       .
# 998       Other Race/ Ethnicity     52             .                       .
# 999          White Non-Hispanic    245          18.3                    15.6
#
# [494 rows x 7 columns]

# %%
male_2016 = deaths_df[mask3 & mask10]

# %% [markdown]
# ### This is for the males in 2016

# %%
male_2016
# Out:
#      year                                      leading_cause   sex  \
# 137  2016            Influenza (Flu) and Pneumonia (J09-J18)  Male
# 138  2016     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Male
# 139  2016              Malignant Neoplasms (Cancer: C00-C97)  Male
# 182  2016                                   All Other Causes  Male
# 183  2016  Certain Conditions originating in the Perinata...  Male
# ..    ...                                                ...   ...
# 268  2016  Essential Hypertension and Renal Diseases (I10...  Male
# 269  2016  Accidents Except Drug Poisoning (V01-X39, X43,...  Male
# 275  2016       Chronic Lower Respiratory Diseases (J40-J47)  Male
# 277  2016                        Diabetes Mellitus (E10-E14)  Male
# 279  2016          Cerebrovascular Disease (Stroke: I60-I69)  Male
#
#                  race_ethnicity deaths    death_rate age_adjusted_death_rate
# 137  Asian and Pacific Islander    113  19.027765383            22.916327557
# 138  Asian and Pacific Islander    603  101.53754448            117.77966521
# 139  Asian and Pacific Islander    683  115.00852882            121.07853677
# 182       Other Race/ Ethnicity     10           NaN                     NaN
# 183       Other Race/ Ethnicity      1           NaN                     NaN
# ..                          ...    ...           ...                     ...
# 268  Asian and Pacific Islander     48   8.082590605            9.8342460156
# 269  Asian and Pacific Islander     60  10.103238256            11.082290293
# 275  Asian and Pacific Islander     75   12.62904782            15.580556412
# 277  Asian and Pacific Islander     76  12.797435125            14.194347138
# 279  Asian and Pacific Islander     95  15.996793906            18.071424317
#
# [71 rows x 7 columns]

# %%
# let's see 
female_2016 = deaths_df[mask3 & mask4]

# %% [markdown]
# ### This is for the females in 2016

# %%
female_2016
# Out:
#      year                                      leading_cause     sex  \
# 136  2016  Human Immunodeficiency Virus Disease (HIV: B20...  Female
# 140  2016                                   All Other Causes  Female
# 141  2016  Nephritis, Nephrotic Syndrome and Nephrisis (N...  Female
# 142  2016                               Septicemia (A40-A41)  Female
# 143  2016                                   All Other Causes  Female
# ..    ...                                                ...     ...
# 273  2016  Essential Hypertension and Renal Diseases (I10...  Female
# 274  2016       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 276  2016            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 278  2016                          Alzheimer's Disease (G30)  Female
# 280  2016  Mental and Behavioral Disorders due to Acciden...  Female
#
#             race_ethnicity deaths    death_rate age_adjusted_death_rate
# 136     Non-Hispanic Black     91  8.7532824809            7.8444021693
# 140  Other Race/ Ethnicity     13           NaN                     NaN
# 141  Other Race/ Ethnicity      1           NaN                     NaN
# 142  Other Race/ Ethnicity      1           NaN                     NaN
# 143     Non-Hispanic Black   1585  152.46101904            127.83742578
# ..                     ...    ...           ...                     ...
# 273     Non-Hispanic Black    226  21.738921326            16.686833576
# 274     Non-Hispanic Black    218  20.969401987            16.849136505
# 276     Non-Hispanic Black    212  20.392262483            16.053811074
# 278     Non-Hispanic Black    158  15.198006945            11.060385285
# 280     Non-Hispanic Black    101  9.7151816547            8.5902035184
#
# [74 rows x 7 columns]

# %%
# have the highest death rate be at the top and set in place 
female_2016.sort_values('death_rate', ascending=False, inplace = True)
# Out:
# C:\Users\13476\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# here is the dataframe 
female_2016
# Out:
#      year                                      leading_cause     sex  \
# 231  2016              Malignant Neoplasms (Cancer: C00-C97)  Female
# 171  2016  Mental and Behavioral Disorders due to Acciden...  Female
# 280  2016  Mental and Behavioral Disorders due to Acciden...  Female
# 265  2016                                   All Other Causes  Female
# 209  2016              Malignant Neoplasms (Cancer: C00-C97)  Female
# ..    ...                                                ...     ...
# 177  2016  Certain Conditions originating in the Perinata...  Female
# 178  2016       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 179  2016          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 180  2016            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 181  2016                        Diabetes Mellitus (E10-E14)  Female
#
#                  race_ethnicity deaths    death_rate age_adjusted_death_rate
# 231                    Hispanic   1162  90.688436054            93.111685142
# 171          Non-Hispanic White    138  9.8498820869            9.3751240527
# 280          Non-Hispanic Black    101  9.7151816547            8.5902035184
# 265                    Hispanic   1147  89.517759168            91.938986348
# 209  Asian and Pacific Islander    565  86.442985878            83.074455608
# ..                          ...    ...           ...                     ...
# 177          Not Stated/Unknown     15           NaN                     NaN
# 178          Not Stated/Unknown     16           NaN                     NaN
# 179          Not Stated/Unknown     18           NaN                     NaN
# 180          Not Stated/Unknown     18           NaN                     NaN
# 181       Other Race/ Ethnicity      3           NaN                     NaN
#
# [74 rows x 7 columns]

# %% [markdown]
# ## Let's find out for each ethnicity

# %%
female_2016['race_ethnicity'].value_counts()
# Out:
# Other Race/ Ethnicity         18
# Not Stated/Unknown            12
# Non-Hispanic White            11
# Non-Hispanic Black            11
# Hispanic                      11
# Asian and Pacific Islander    11
# White Non-Hispanic             0
# Black Non-Hispanic             0
# Name: race_ethnicity, dtype: int64

# %% [markdown]
# ## This is for the Hispanic Females

# %%
# creating a  mask for the female hispanics 
mask5 = female_2016['race_ethnicity'] == 'Hispanic'

# %% [markdown]
# #### We can see from the below dataframe that heart disease is the highest leading_cause of death for Hispanic Women in 2016

# %%
df_1 = female_2016[mask5]

# %%
female_2016[mask5]
# Out:
#      year                                      leading_cause     sex  \
# 231  2016              Malignant Neoplasms (Cancer: C00-C97)  Female
# 265  2016                                   All Other Causes  Female
# 262  2016  Mental and Behavioral Disorders due to Acciden...  Female
# 263  2016  Chronic Liver Disease and Cirrhosis (K70, K73-...  Female
# 239  2016                        Diabetes Mellitus (E10-E14)  Female
# 247  2016          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 250  2016                          Alzheimer's Disease (G30)  Female
# 252  2016            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 259  2016       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 230  2016     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 261  2016  Essential Hypertension and Renal Diseases (I10...  Female
#
#     race_ethnicity deaths    death_rate age_adjusted_death_rate
# 231       Hispanic   1162  90.688436054            93.111685142
# 265       Hispanic   1147  89.517759168            91.938986348
# 262       Hispanic     90  7.0240613123            6.8554556055
# 263       Hispanic     59  4.6046624158            4.6851572028
# 239       Hispanic    231  18.028424035            18.561319552
# 247       Hispanic    204  15.921205641            16.428438473
# 250       Hispanic    203  15.843160515            16.480112491
# 252       Hispanic    195   15.21879951            15.840548354
# 259       Hispanic    168  13.111581116            13.562403009
# 230       Hispanic   1485  115.89701165            120.31531124
# 261       Hispanic    131  10.223911466            10.490616754

# %%
# converting the deaths into 'int' so we can plot 
df_1['deaths'] = df_1['deaths'].astype('int')
# Out:
# C:\Users\13476\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1.plot( x = 'leading_cause', y = 'deaths', kind = 'bar', figsize = (10,5))

# %% [markdown]
# ## This is for White females

# %%
mask6 = female_2016['race_ethnicity'] == 'Non-Hispanic White'

# %% [markdown]
# #### We can see that for White females in 2016 the leading cause of death is heart disease

# %%
df_2 = female_2016[mask6]

# %%
df_2
# Out:
#      year                                      leading_cause     sex  \
# 171  2016  Mental and Behavioral Disorders due to Acciden...  Female
# 148  2016       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 152  2016            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 145  2016     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 154  2016          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 155  2016                          Alzheimer's Disease (G30)  Female
# 147  2016              Malignant Neoplasms (Cancer: C00-C97)  Female
# 172  2016                                   All Other Causes  Female
# 157  2016  Essential Hypertension and Renal Diseases (I10...  Female
# 161  2016                        Diabetes Mellitus (E10-E14)  Female
# 167  2016  Accidents Except Drug Poisoning (V01-X39, X43,...  Female
#
#          race_ethnicity deaths    death_rate age_adjusted_death_rate
# 171  Non-Hispanic White    138  9.8498820869            9.3751240527
# 148  Non-Hispanic White    471  33.618075818            19.479202301
# 152  Non-Hispanic White    450  32.119180718            17.149186714
# 145  Non-Hispanic White   4306  307.34487149            156.26533327
# 154  Non-Hispanic White    404  28.835886689             15.15839983
# 155  Non-Hispanic White    361  25.766720532            11.757162066
# 147  Non-Hispanic White   3102  221.40821908            149.01344792
# 172  Non-Hispanic White   2416  172.44431248              102.399688
# 157  Non-Hispanic White    219  15.631334616            8.2112950139
# 161  Non-Hispanic White    183  13.061800159             8.011416512
# 167  Non-Hispanic White    156  11.134649316            7.2336520293

# %%
# converting the deaths into 'int' so we can plot 
df_2['deaths'] = df_2['deaths'].astype('int')
# Out:
# C:\Users\13476\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_2.plot( x = 'leading_cause', y = 'deaths', kind = 'bar', figsize = (10,5))

# %% [markdown]
# ## This is for Black females

# %%
mask7 = female_2016['race_ethnicity'] == 'Non-Hispanic Black'

# %% [markdown]
# #### We can see that Black women in 2016, the leading cause of death is heart disease

# %%
df_3 = female_2016[mask7]

# %%
df_3
# Out:
#      year                                      leading_cause     sex  \
# 280  2016  Mental and Behavioral Disorders due to Acciden...  Female
# 136  2016  Human Immunodeficiency Virus Disease (HIV: B20...  Female
# 271  2016                        Diabetes Mellitus (E10-E14)  Female
# 272  2016          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 266  2016     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 273  2016  Essential Hypertension and Renal Diseases (I10...  Female
# 274  2016       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 276  2016            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 270  2016              Malignant Neoplasms (Cancer: C00-C97)  Female
# 143  2016                                   All Other Causes  Female
# 278  2016                          Alzheimer's Disease (G30)  Female
#
#          race_ethnicity deaths    death_rate age_adjusted_death_rate
# 280  Non-Hispanic Black    101  9.7151816547            8.5902035184
# 136  Non-Hispanic Black     91  8.7532824809            7.8444021693
# 271  Non-Hispanic Black    399  38.379777032            30.807579371
# 272  Non-Hispanic Black    276  26.548417195            20.695012466
# 266  Non-Hispanic Black   2303  221.52537971            171.09966165
# 273  Non-Hispanic Black    226  21.738921326            16.686833576
# 274  Non-Hispanic Black    218  20.969401987            16.849136505
# 276  Non-Hispanic Black    212  20.392262483            16.053811074
# 270  Non-Hispanic Black   1864  179.29800598            145.04080515
# 143  Non-Hispanic Black   1585  152.46101904            127.83742578
# 278  Non-Hispanic Black    158  15.198006945            11.060385285

# %%
# converting the deaths into 'int' so we can plot 
df_3['deaths'] = df_3['deaths'].astype('int')
# Out:
# C:\Users\13476\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_3.plot( x = 'leading_cause', y = 'deaths', kind = 'bar', figsize = (10,5))

# %% [markdown]
# ## This is for Asian and Pacific Islander females

# %%
mask8 = female_2016['race_ethnicity'] == 'Asian and Pacific Islander'

# %% [markdown]
# #### We can see that for Asian and Pacific Islander women the leading cause of death is malignant neoplasms

# %%
df_4 = female_2016[mask8]

# %%
df_4
# Out:
#      year                                      leading_cause     sex  \
# 209  2016              Malignant Neoplasms (Cancer: C00-C97)  Female
# 214  2016     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 221  2016  Essential Hypertension and Renal Diseases (I10...  Female
# 224  2016                          Alzheimer's Disease (G30)  Female
# 225  2016  Accidents Except Drug Poisoning (V01-X39, X43,...  Female
# 228  2016                                   All Other Causes  Female
# 226  2016       Chronic Lower Respiratory Diseases (J40-J47)  Female
# 227  2016  Intentional Self-Harm (Suicide: U03, X60-X84, ...  Female
# 217  2016          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 218  2016            Influenza (Flu) and Pneumonia (J09-J18)  Female
# 220  2016                        Diabetes Mellitus (E10-E14)  Female
#
#                  race_ethnicity deaths    death_rate age_adjusted_death_rate
# 209  Asian and Pacific Islander    565  86.442985878            83.074455608
# 214  Asian and Pacific Islander    530  81.088110647            82.628287468
# 221  Asian and Pacific Islander     58  8.8737932406             9.168902731
# 224  Asian and Pacific Islander     49   7.496825324            7.7427823549
# 225  Asian and Pacific Islander     43  6.5788467129            6.5005947989
# 228  Asian and Pacific Islander    385  58.903627545            60.884572245
# 226  Asian and Pacific Islander     39  5.9668609721            6.1103990707
# 227  Asian and Pacific Islander     29  4.4368966203            4.1497478057
# 217  Asian and Pacific Islander    118  18.053579352            18.250674863
# 218  Asian and Pacific Islander     92  14.075672037            14.459470243
# 220  Asian and Pacific Islander     73  11.168739768            11.233526052

# %%
# converting the deaths into 'int' so we can plot 
df_4['deaths'] = df_4['deaths'].astype('int')
# Out:
# C:\Users\13476\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_4.plot( x = 'leading_cause', y = 'deaths', kind = 'bar', figsize = (10,5))
